# %% [markdown]
# # Parsing transcript data
#
# This notebook matches the transactions with the offers if there were any when the transaction was made.

# %%
import pandas as pd
import numpy as np
from src.utils.parse_transcript import parse_transcript, get_transaction_dataframe

# %%
# Load data
portfolio = pd.read_csv('./data/final/portfolio.csv')
transcript = pd.read_csv('./data/final/transcript.csv')

# %% [markdown]
# ## Portfolio data

# %%
# Create a dictionary to store portfolio validity
portfolio_validity = {
    offer: duration
    for offer, duration
    in portfolio[['offer', 'duration']].values
}

portfolio_validity
# Out:
# {'ae264e3637204a6fb9bb56bc8210ddfd': 168,
#  '4d5c57ea9a6940dd891ad53e9dbe8da0': 120,
#  '3f207df678b143eea3cee63160fa8bed': 96,
#  '9b98b8c7a33c4b65b9aebfe6a799e6d9': 168,
#  '0b1e1539f2cc45b7b9fa7c272da2e1d7': 240,
#  '2298d6c36e964ae4a3e7e9706d1fb8c2': 168,
#  'fafdcd668e3743c1bb461111dcafc2a4': 240,
#  '5a8bc65990b245e5a138643cd4eb9837': 72,
#  'f19421c1d4aa40978ebb69ca19b0e20d': 120,
#  '2906b810c7d4411798c6938adc9daaa5': 168}

# %% [markdown]
# ## Transcript data

# %%
transcript.head(10)
# Out:
#    amount  reward                            person           event  time  \
# 0     NaN     NaN  78afa995795e4d85b5d9ceeca43f5fef  offer received     0
# 1     NaN     NaN  a03223e636434f42ac4c3df47e8bac43  offer received     0
# 2     NaN     NaN  e2127556f4f64592b11af22de27a7932  offer received     0
# 3     NaN     NaN  8ec6ce2a7e7949b1bf142def7d0e0586  offer received     0
# 4     NaN     NaN  68617ca6246f4fbc85e91a2a49552598  offer received     0
# 5     NaN     NaN  389bc3fa690240e798340f5a15918d5c  offer received     0
# 6     NaN     NaN  c4863c7985cf408faee930f111475da3  offer received     0
# 7     NaN     NaN  2eeac8d8feae4a8cad5a6af0499a211d  offer received     0
# 8     NaN     NaN  aa4862eba776480b8bb9c68455b8c2e1  offer received     0
# 9     NaN     NaN  31dda685af34476cad5bc968bdb01c53  offer received     0
#
#                               offer
# 0  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 1  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 2  2906b810c7d4411798c6938adc9daaa5
# 3  fafdcd668e3743c1bb461111dcafc2a4
# 4  4d5c57ea9a6940dd891ad53e9dbe8da0
# 5  f19421c1d4aa40978ebb69ca19b0e20d
# 6  2298d6c36e964ae4a3e7e9706d1fb8c2
# 7  3f207df678b143eea3cee63160fa8bed
# 8  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 9  0b1e1539f2cc45b7b9fa7c272da2e1d7

# %%
# Match offers and transactions
transaction_list = parse_transcript(transcript, portfolio_validity)
transaction_df = get_transaction_dataframe(transaction_list)

transaction_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-02050ed8d109> in <module>
#       1 # Match offers and transactions
# ----> 2 transaction_list = parse_transcript(transcript, portfolio_validity)
#       3 transaction_df = get_transaction_dataframe(transaction_list)
#       4
#       5 transaction_df.head(10)
#
# c:\Users\vu86683\Desktop\learn\starbucks-offer-optimisation\src\utils\parse_transcript.py in parse_transcript(transcript, portfolio_validity)
#      36             # Decay validity of all current offers
#      37             if customer_log.last_timestamp != current_timestamp:
# ---> 38                 customer_log.decay_offer_validity(current_timestamp)
#      39
#      40             if event_type == 'offer received':
#
# c:\Users\vu86683\Desktop\learn\starbucks-offer-optimisation\src\utils\customer_log.py in decay_offer_validity(self, current_timestamp)
#      22         for offer_id in self.current_offers:
#      23             time_passed = current_timestamp - self.last_timestamp
# ---> 24             offer_time_left = self.current_offers[offer_id]['time_left'] - time_passed
#      25             if offer_time_left < 0:
#      26                 self.expire_offer(offer_id)
#
# KeyError: 'time_left'

# %%
transaction_df.to_csv('./data/final/transaction_frame.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-596b987eed82> in <module>
# ----> 1 transaction_df.to_csv('./data/final/transaction_frame.csv', index=False)
#
# NameError: name 'transaction_df' is not defined
